# %% [markdown]
# <a href="https://colab.research.google.com/github/gungunkhatana/Brain-tumour-detection/blob/main/Untitled10.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install opendatasets

# %%
import opendatasets as od

od.download("https://www.kaggle.com/datasets/masoudnickparvar/brain-tumor-mri-dataset")
# Out:
# Please provide your Kaggle credentials to download this dataset. Learn more: http://bit.ly/kaggle-creds
# Your Kaggle username: h
# Your Kaggle Key: ··········
# Dataset URL: https://www.kaggle.com/datasets/masoudnickparvar/brain-tumor-mri-dataset
# ...
# 100%|██████████| 149M/149M [00:01<00:00, 78.6MB/s]

# %%
import os
from PIL import Image
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from glob import glob

from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report, confusion_matrix

import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, Flatten
from tensorflow.keras.optimizers import Adamax
from tensorflow.keras.metrics import Precision, Recall
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# import warnings
# warnings.filterwarnings("ignore")

# %%
def train_df(tr_path):
    classes, class_paths = zip(*[(label, os.path.join(tr_path, label, image))
                                 for label in os.listdir(tr_path) if os.path.isdir(os.path.join(tr_path, label))
                                 for image in os.listdir(os.path.join(tr_path, label))])

    tr_df = pd.DataFrame({'Class Path': class_paths, 'Class': classes})
    return tr_df
def test_df(ts_path):
    classes, class_paths = zip(*[(label, os.path.join(ts_path, label, image))
                                 for label in os.listdir(ts_path) if os.path.isdir(os.path.join(ts_path, label))
                                 for image in os.listdir(os.path.join(ts_path, label))])

    ts_df = pd.DataFrame({'Class Path': class_paths, 'Class': classes})
    return ts_df

# %%
tr_df = train_df('./brain-tumor-mri-dataset/Training')
tr_df
# Out:
#                                              Class Path       Class
# 0     ./brain-tumor-mri-dataset/Training/meningioma/...  meningioma
# 1     ./brain-tumor-mri-dataset/Training/meningioma/...  meningioma
# 2     ./brain-tumor-mri-dataset/Training/meningioma/...  meningioma
# 3     ./brain-tumor-mri-dataset/Training/meningioma/...  meningioma
# 4     ./brain-tumor-mri-dataset/Training/meningioma/...  meningioma
# ...                                                 ...         ...
# 5707  ./brain-tumor-mri-dataset/Training/glioma/Tr-g...      glioma
# 5708  ./brain-tumor-mri-dataset/Training/glioma/Tr-g...      glioma
# 5709  ./brain-tumor-mri-dataset/Training/glioma/Tr-g...      glioma
# 5710  ./brain-tumor-mri-dataset/Training/glioma/Tr-g...      glioma
# 5711  ./brain-tumor-mri-dataset/Training/glioma/Tr-g...      glioma
#
# [5712 rows x 2 columns]

# %%
ts_df = test_df('./brain-tumor-mri-dataset/Testing')
ts_df
# Out:
#                                              Class Path       Class
# 0     ./brain-tumor-mri-dataset/Testing/meningioma/T...  meningioma
# 1     ./brain-tumor-mri-dataset/Testing/meningioma/T...  meningioma
# 2     ./brain-tumor-mri-dataset/Testing/meningioma/T...  meningioma
# 3     ./brain-tumor-mri-dataset/Testing/meningioma/T...  meningioma
# 4     ./brain-tumor-mri-dataset/Testing/meningioma/T...  meningioma
# ...                                                 ...         ...
# 1306  ./brain-tumor-mri-dataset/Testing/glioma/Te-gl...      glioma
# 1307  ./brain-tumor-mri-dataset/Testing/glioma/Te-gl...      glioma
# 1308  ./brain-tumor-mri-dataset/Testing/glioma/Te-gl...      glioma
# 1309  ./brain-tumor-mri-dataset/Testing/glioma/Te-gl...      glioma
# 1310  ./brain-tumor-mri-dataset/Testing/glioma/Te-gl...      glioma
#
# [1311 rows x 2 columns]

# %%
plt.figure(figsize=(5,3))
ax = sns.countplot(data=tr_df , y=tr_df['Class'])

plt.xlabel('')
plt.ylabel('')
plt.title('Count of images in each class', fontsize=20)
ax.bar_label(ax.containers[0])
plt.show()

# %%
plt.figure(figsize=(5, 3))
ax = sns.countplot(y=ts_df['Class'], palette='viridis')

ax.set(xlabel='', ylabel='', title='Count of images in each class')
ax.bar_label(ax.containers[0])

plt.show()
# Out:
# <ipython-input-8-3be0e08bc94c>:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sns.countplot(y=ts_df['Class'], palette='viridis')

# %%
valid_df, ts_df = train_test_split(ts_df, train_size=0.5, random_state=20, stratify=ts_df['Class'])

# %%
batch_size = 32
img_size = (299, 299)

_gen = ImageDataGenerator(rescale=1/255,
                          brightness_range=(0.8, 1.2))

ts_gen = ImageDataGenerator(rescale=1/255)

# print(ts_gen)
tr_gen = _gen.flow_from_dataframe(tr_df, x_col='Class Path',
                                  y_col='Class', batch_size=batch_size,
                                  target_size=img_size)

valid_gen = _gen.flow_from_dataframe(valid_df, x_col='Class Path',
                                     y_col='Class', batch_size=batch_size,
                                     target_size=img_size)

ts_gen = ts_gen.flow_from_dataframe(ts_df, x_col='Class Path',
                                  y_col='Class', batch_size=16,
                                  target_size=img_size, shuffle=False)
# Out:
# Found 5712 validated image filenames belonging to 4 classes.
# Found 655 validated image filenames belonging to 4 classes.
# Found 656 validated image filenames belonging to 4 classes.

# %%
class_dict = tr_gen.class_indices
classes = list(class_dict.keys())
images, labels = next(ts_gen)

# %%
plt.figure(figsize=(12, 15))

for i, (image, label) in enumerate(zip(images, labels)):
    plt.subplot(4,4, i + 1)
    plt.imshow(image)
    class_name = classes[np.argmax(label)]
    plt.title(class_name, color='k', fontsize=15)

plt.show()

# %%
pip install tensorflow

# %%
from tensorflow.keras.layers import Lambda
img_shape=(299,299,3)
base_model = tf.keras.applications.Xception(include_top= False, weights= "imagenet",
                            input_shape= img_shape, pooling= 'max')


model = Sequential([
    base_model,
    Flatten(),
    Dropout(rate= 0.3),
    Dense(128, activation= 'relu'),
    Dropout(rate= 0.25),
    Dense(4, activation= 'softmax')
])

model.compile(Adamax(learning_rate= 0.001),
              loss= 'categorical_crossentropy',
              metrics= ['accuracy',
                        Precision(),
                        Recall()])

model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ xception (Functional)                │ (None, 2048)                │      20,861,480 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ flatten (Flatten)                    │ (None, 2048)                │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout (Dropout)                    │ (None, 2048)                │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense (Dense)                        │ (None, 128)                 │         262,272 │
# ...

# %%
tf.keras.utils.plot_model(model, show_shapes=True, dpi=96,)

# %%
import keras
model = keras.saving.load_model("/content/drive/MyDrive/brain_tumor_detection_cnn_99.h5");
# Out:
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.

# %%
hist = model.fit(tr_gen,
                 epochs=10,
                 validation_data=valid_gen,
                 shuffle= False)
# Out:
# Epoch 1/10
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 0s 158ms/step
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-20-294fe3901a63> in <cell line: 1>()
# ----> 1 hist = model.fit(tr_gen,
#       2                  epochs=10,
#       3                  validation_data=valid_gen,
#       4                  shuffle= False)
#
# /usr/local/lib/python3.10/dist-packages/keras/src/utils/traceback_utils.py in error_handler(*args, **kwargs)
#     120             # To get the full stack trace, call:
#     121             # `keras.config.disable_traceback_filtering()`
# --> 122             raise e.with_traceback(filtered_tb) from None
#     123         finally:
#     124             del filtered_tb
#
# ...

# %%
hist.history.keys()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-15-932b110bcfbb> in <cell line: 1>()
# ----> 1 hist.history.keys()
#
# NameError: name 'hist' is not defined

# %%
tr_acc = hist.history['accuracy']
tr_loss = hist.history['loss']
tr_per = hist.history['precision']
tr_recall = hist.history['recall']
val_acc = hist.history['val_accuracy']
val_loss = hist.history['val_loss']
val_per = hist.history['val_precision']
val_recall = hist.history['val_recall']

index_loss = np.argmin(val_loss)
val_lowest = val_loss[index_loss]
index_acc = np.argmax(val_acc)
acc_highest = val_acc[index_acc]
index_precision = np.argmax(val_per)
per_highest = val_per[index_precision]
index_recall = np.argmax(val_recall)
recall_highest = val_recall[index_recall]

Epochs = [i + 1 for i in range(len(tr_acc))]
loss_label = f'Best epoch = {str(index_loss + 1)}'
acc_label = f'Best epoch = {str(index_acc + 1)}'
per_label = f'Best epoch = {str(index_precision + 1)}'
recall_label = f'Best epoch = {str(index_recall + 1)}'


plt.figure(figsize=(20, 12))
plt.style.use('fivethirtyeight')


plt.subplot(2, 2, 1)
plt.plot(Epochs, tr_loss, 'r', label='Training loss')
plt.plot(Epochs, val_loss, 'g', label='Validation loss')
plt.scatter(index_loss + 1, val_lowest, s=150, c='blue', label=loss_label)
plt.title('Training and Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.grid(True)

plt.subplot(2, 2, 2)
plt.plot(Epochs, tr_acc, 'r', label='Training Accuracy')
plt.plot(Epochs, val_acc, 'g', label='Validation Accuracy')
plt.scatter(index_acc + 1, acc_highest, s=150, c='blue', label=acc_label)
plt.title('Training and Validation Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.grid(True)

plt.subplot(2, 2, 3)
plt.plot(Epochs, tr_per, 'r', label='Precision')
plt.plot(Epochs, val_per, 'g', label='Validation Precision')
plt.scatter(index_precision + 1, per_highest, s=150, c='blue', label=per_label)
plt.title('Precision and Validation Precision')
plt.xlabel('Epochs')
plt.ylabel('Precision')
plt.legend()
plt.grid(True)

plt.subplot(2, 2, 4)
plt.plot(Epochs, tr_recall, 'r', label='Recall')
plt.plot(Epochs, val_recall, 'g', label='Validation Recall')
plt.scatter(index_recall + 1, recall_highest, s=150, c='blue', label=recall_label)
plt.title('Recall and Validation Recall')
plt.xlabel('Epochs')
plt.ylabel('Recall')
plt.legend()
plt.grid(True)

plt.suptitle('Model Training Metrics Over Epochs', fontsize=16)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-85230e8824a0> in <cell line: 1>()
# ----> 1 tr_acc = hist.history['accuracy']
#       2 tr_loss = hist.history['loss']
#       3 tr_per = hist.history['precision']
#       4 tr_recall = hist.history['recall']
#       5 val_acc = hist.history['val_accuracy']
#
# NameError: name 'hist' is not defined

# %%
pip install keras

# %%
import keras
model = keras.models.load_model('./drive/MyDrive/brain_tumor_detection_cnn_99.h5')
# Out:
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.

# %%
train_score = model.evaluate(tr_gen, verbose=1)
valid_score = model.evaluate(valid_gen, verbose=1)
test_score = model.evaluate(ts_gen, verbose=1)

print(f"Train Loss: {train_score[0]:.4f}")
print(f"Train Accuracy: {train_score[1]*100:.2f}%")
print('-' * 20)
print(f"Validation Loss: {valid_score[0]:.4f}")
print(f"Validation Accuracy: {valid_score[1]*100:.2f}%")
print('-' * 20)
print(f"Test Loss: {test_score[0]:.4f}")
print(f"Test Accuracy: {test_score[1]*100:.2f}%")
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:122: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 82s 310ms/step - accuracy: 0.9992 - loss: 0.0025 - precision: 0.9992 - recall: 0.9992
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 18s 856ms/step - accuracy: 0.9880 - loss: 0.0441 - precision: 0.9880 - recall: 0.9880
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 5s 120ms/step - accuracy: 0.9920 - loss: 0.0205 - precision: 0.9920 - recall: 0.9920
# Train Loss: 0.0021
# Train Accuracy: 99.95%
# --------------------
# Validation Loss: 0.0383
# Validation Accuracy: 99.08%
# --------------------
# Test Loss: 0.0296
# Test Accuracy: 98.93%

# %%
preds = model.predict(ts_gen)
y_pred = np.argmax(preds, axis=1)
# Out:
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 7s 100ms/step

# %%
cm = confusion_matrix(ts_gen.classes, y_pred)
labels = list(class_dict.keys())
plt.figure(figsize=(5, 4))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=labels, yticklabels=labels)
plt.xlabel('Predicted Label')
plt.ylabel('Truth Label')
plt.show()

# %%
clr = classification_report(ts_gen.classes, y_pred)
print(clr)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.98      0.98      0.98       150
#            1       0.97      0.99      0.98       153
#            2       1.00      1.00      1.00       203
#            3       1.00      0.99      1.00       150
#
#     accuracy                           0.99       656
#    macro avg       0.99      0.99      0.99       656
# weighted avg       0.99      0.99      0.99       656

# %%
def predict(img_path):
    import numpy as np
    import matplotlib.pyplot as plt
    from PIL import Image
    label = list(class_dict.keys())
    plt.figure(figsize=(6, 6))
    img = Image.open(img_path)
    resized_img = img.resize((299, 299))
    img = np.asarray(resized_img)
    # print(img.shape)
    if img.ndim == 2:
        img = np.expand_dims(img, axis=-1)
        img = np.repeat(img, 3, axis=-1)
    img = np.expand_dims(img, axis=0)
    img = img / 255
    predictions = model.predict(img)
    probs = list(predictions[0])
    labels = label
    plt.subplot(2, 1, 1)
    plt.imshow(resized_img)
    plt.subplot(2, 1, 2)
    bars = plt.barh(labels, probs)
    plt.xlabel('Probability', fontsize=15)
    ax = plt.gca()
    ax.bar_label(bars, fmt = '%.2f')
    plt.show()
    print()
    for i in range(len(probs)):
      print("The probability of the tumor being ", list(class_dict.keys())[i], " is ", probs[i] * 100)
    kmax = list(class_dict.keys())[probs.index(max(probs))]
    print()
    print("The tumor is most likely to be ", kmax)

# %%
predict('./brain-tumor-mri-dataset/Testing/meningioma/Te-meTr_0000.jpg')
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 4s 4s/step
# The probability of the tumor being  glioma  is  1.386827097604737e-06
# The probability of the tumor being  meningioma  is  100.0
# The probability of the tumor being  notumor  is  4.1233452763300704e-08
# The probability of the tumor being  pituitary  is  2.593472936407437e-08
#
# The tumor is most likely to be  meningioma

# %%
predict('/content/MRI-Brain-Images-abenign-bmalignant-images.png')
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# The probability of the tumor being  glioma  is  6.609638530941098e-09
# The probability of the tumor being  meningioma  is  100.0
# The probability of the tumor being  notumor  is  8.994029479514332e-11
# The probability of the tumor being  pituitary  is  1.0167882161238317e-10
#
# The tumor is most likely to be  meningioma

# %%
# !pip install streamlit pyngrok
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.3/44.3 kB 2.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.1/9.1 MB 82.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.9/6.9 MB 73.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.1/79.1 kB 7.5 MB/s eta 0:00:00
# ...

# %%
from pyngrok import ngrok
import subprocess

# Write the Streamlit app code to a file
ngrok.set_auth_token("2q7faKdH4Ggjyf0veWmm9SVI431_5CxYPP66u61XGDnwzpZ9F")

with open("app.py", "w") as f:
    f.write("""
import streamlit as st
import numpy as np
import matplotlib.pyplot as plt
from PIL import Image
import tensorflow as tf

# Load the trained model
model = tf.keras.models.load_model('./drive/MyDrive/brain_tumor_detection_cnn_99.h5')

# Define the class labels based on the model's training
class_dict = {0: 'glioma', 1: 'meningioma', 2: 'no_tumor', 3: 'pituitary'}

# Function to preprocess and predict
@st.cache_data
def predict(img_path):
    labels = list(class_dict.keys())
    img = Image.open(img_path)
    resized_img = img.resize((299, 299))
    img = np.asarray(resized_img)
    if img.ndim == 2:
        img = np.expand_dims(img, axis=-1)
        img = np.repeat(img, 3, axis=-1)
    img = np.expand_dims(img, axis=0)
    img = img / 255
    predictions = model.predict(img)
    probs = list(predictions[0])
    predicted_class = labels[np.argmax(probs)]
    return probs, predicted_class, resized_img

# Streamlit app interface
st.title("Brain Tumor MRI Classification")
st.write("Upload an MRI image to detect the type of brain tumor.")

# File uploader for image
uploaded_file = st.file_uploader("Choose an MRI image", type=["jpg", "jpeg", "png"])

if uploaded_file:
    # Display uploaded image - no need
    # st.image(uploaded_file, caption="Uploaded Image", use_column_width=True)
    st.write("Processing...")

    # Predict the image class
    probs, predicted_class, resized_img = predict(uploaded_file)

    # Display results
    st.image(resized_img, caption=f"Resized Image (299x299)", use_column_width=True)

    # Plot probabilities
    fig, ax = plt.subplots()
    bars = ax.barh(list(class_dict.values()), probs, color='skyblue')
    ax.set_xlabel('Probability')
    ax.set_title('Class Probabilities')
    ax.bar_label(bars, fmt='%.2f')
    st.pyplot(fig)

    st.write(f"### Prediction: {predicted_class}")

    # Display probabilities for all classes
    st.write("#### Class Probabilities:")
    for i, label in enumerate(class_dict.values()):
        st.write(f"{label}: {probs[i] * 100:.2f}%")
""")

# Run Streamlit app
streamlit_process = subprocess.Popen(["streamlit", "run", "app.py"])

# Expose the Streamlit app to the internet
public_url = ngrok.connect(8501, "http")  # Explicitly specify the port and protocol
print(f"Streamlit app is live at: {public_url}")
# Out:
# Streamlit app is live at: NgrokTunnel: "https://146b-34-125-187-4.ngrok-free.app" -> "http://localhost:8501"

# %%
# !pkill -f ngrok
